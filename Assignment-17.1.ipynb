# %%
import numpy as np
import pandas as pd
import scipy
import scipy.stats as stats
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
Number_Questions = 20
Question_Probability = 1/4
Probability_Five_Wrong = 5
hh = stats.binom(Number_Questions, Question_Probability)
total_p = 0

for k in range(1, Probability_Five_Wrong + 1): # DO NOT FORGET THAT THE LAST INDEX IS NOT USED
 total_p += hh.pmf(k)

total_p
# Out:
# 0.6140014424481692

# %%
# scipy.linspace(start, stop, num_elements)
x = scipy.linspace(1,20,20)
pmf = stats.binom.pmf(x,20,total_p)
plt.plot(x,pmf)
